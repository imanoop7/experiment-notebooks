# %%
pip install unstructured[all]
# Out:
# Collecting unstructured[all]
#   Downloading unstructured-0.15.0-py3-none-any.whl.metadata (29 kB)
# Collecting chardet (from unstructured[all])
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting filetype (from unstructured[all])
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting python-magic (from unstructured[all])
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting lxml (from unstructured[all])
#   Using cached lxml-5.2.2-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Collecting nltk (from unstructured[all])
#   Using cached nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting tabulate (from unstructured[all])
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting requests (from unstructured[all])
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting beautifulsoup4 (from unstructured[all])
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting emoji (from unstructured[all])
#   Downloading emoji-2.12.1-py3-none-any.whl.metadata (5.4 kB)
# Collecting dataclasses-json (from unstructured[all])
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting python-iso639 (from unstructured[all])
#   Downloading python_iso639-2024.4.27-py3-none-any.whl.metadata (13 kB)
# Collecting langdetect (from unstructured[all])
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      -- ------------------------------------ 61.4/981.5 kB 1.7 MB/s eta 0:00:01
#      --- ----------------------------------- 92.2/981.5 kB 1.1 MB/s eta 0:00:01
#      ---- --------------------------------- 112.6/981.5 kB 1.1 MB/s eta 0:00:01
#      -------- ----------------------------- 225.3/981.5 kB 1.4 MB/s eta 0:00:01
#      --------- ---------------------------- 245.8/981.5 kB 1.3 MB/s eta 0:00:01
#      ----------- -------------------------- 286.7/981.5 kB 1.1 MB/s eta 0:00:01
#      ----------- -------------------------- 286.7/981.5 kB 1.1 MB/s eta 0:00:01
#      ---------------- --------------------- 419.8/981.5 kB 1.1 MB/s eta 0:00:01
#      ------------------- ------------------ 501.8/981.5 kB 1.3 MB/s eta 0:00:01
#      --------------------- ---------------- 553.0/981.5 kB 1.2 MB/s eta 0:00:01
#      ------------------------ ------------- 634.9/981.5 kB 1.2 MB/s eta 0:00:01
#      --------------------------- ---------- 716.8/981.5 kB 1.3 MB/s eta 0:00:01
#      -------------------------------- ----- 829.4/981.5 kB 1.4 MB/s eta 0:00:01
#      ----------------------------------- -- 911.4/981.5 kB 1.4 MB/s eta 0:00:01
#      -------------------------------------  972.8/981.5 kB 1.5 MB/s eta 0:00:01
#      -------------------------------------- 981.5/981.5 kB 1.4 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting numpy<2 (from unstructured[all])
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Collecting rapidfuzz (from unstructured[all])
#   Downloading rapidfuzz-3.9.4-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Collecting backoff (from unstructured[all])
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting typing-extensions (from unstructured[all])
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting unstructured-client (from unstructured[all])
#   Downloading unstructured_client-0.24.1-py3-none-any.whl.metadata (12 kB)
# Collecting wrapt (from unstructured[all])
#   Using cached wrapt-1.16.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Collecting tqdm (from unstructured[all])
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: psutil in c:\users\anoop maurya\documents\github\experiment-notebooks\.venv\lib\site-packages (from unstructured[all]) (6.0.0)
# Collecting soupsieve>1.2 (from beautifulsoup4->unstructured[all])
#   Using cached soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->unstructured[all])
#   Using cached marshmallow-3.21.3-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json->unstructured[all])
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: six in c:\users\anoop maurya\documents\github\experiment-notebooks\.venv\lib\site-packages (from langdetect->unstructured[all]) (1.16.0)
# Collecting click (from nltk->unstructured[all])
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting joblib (from nltk->unstructured[all])
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting regex>=2021.8.3 (from nltk->unstructured[all])
#   Using cached regex-2024.5.15-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Collecting charset-normalizer<4,>=2 (from requests->unstructured[all])
#   Using cached charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests->unstructured[all])
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->unstructured[all])
#   Using cached urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests->unstructured[all])
#   Using cached certifi-2024.7.4-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: colorama in c:\users\anoop maurya\documents\github\experiment-notebooks\.venv\lib\site-packages (from tqdm->unstructured[all]) (0.4.6)
# Collecting deepdiff>=6.0 (from unstructured-client->unstructured[all])
#   Downloading deepdiff-7.0.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx>=0.27.0 (from unstructured-client->unstructured[all])
#   Using cached httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting jsonpath-python>=1.0.6 (from unstructured-client->unstructured[all])
#   Downloading jsonpath_python-1.0.6-py3-none-any.whl.metadata (12 kB)
# Collecting mypy-extensions>=1.0.0 (from unstructured-client->unstructured[all])
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: nest-asyncio>=1.6.0 in c:\users\anoop maurya\documents\github\experiment-notebooks\.venv\lib\site-packages (from unstructured-client->unstructured[all]) (1.6.0)
# Requirement already satisfied: packaging>=23.1 in c:\users\anoop maurya\documents\github\experiment-notebooks\.venv\lib\site-packages (from unstructured-client->unstructured[all]) (24.1)
# Collecting pypdf>=4.0 (from unstructured-client->unstructured[all])
#   Downloading pypdf-4.3.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\anoop maurya\documents\github\experiment-notebooks\.venv\lib\site-packages (from unstructured-client->unstructured[all]) (2.9.0.post0)
# Collecting requests-toolbelt>=1.0.0 (from unstructured-client->unstructured[all])
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting ordered-set<4.2.0,>=4.1.0 (from deepdiff>=6.0->unstructured-client->unstructured[all])
#   Downloading ordered_set-4.1.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting anyio (from httpx>=0.27.0->unstructured-client->unstructured[all])
#   Using cached anyio-4.4.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting httpcore==1.* (from httpx>=0.27.0->unstructured-client->unstructured[all])
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting sniffio (from httpx>=0.27.0->unstructured-client->unstructured[all])
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured[all])
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#    ---------------------------------------- 0.0/199.4 kB ? eta -:--:--
#    ---------------------- ----------------- 112.6/199.4 kB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  194.6/199.4 kB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 199.4/199.4 kB 1.5 MB/s eta 0:00:00
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading emoji-2.12.1-py3-none-any.whl (431 kB)
#    ---------------------------------------- 0.0/431.4 kB ? eta -:--:--
#    ------------------ --------------------- 204.8/431.4 kB 6.3 MB/s eta 0:00:01
#    -------------------------- ------------- 286.7/431.4 kB 2.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 378.9/431.4 kB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  430.1/431.4 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  430.1/431.4 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  430.1/431.4 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  430.1/431.4 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  430.1/431.4 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  430.1/431.4 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  430.1/431.4 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  430.1/431.4 kB 3.0 MB/s eta 0:00:01
#    -------------------------------------- 431.4/431.4 kB 769.9 kB/s eta 0:00:00
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Using cached lxml-5.2.2-cp312-cp312-win_amd64.whl (3.8 MB)
# Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Downloading python_iso639-2024.4.27-py3-none-any.whl (274 kB)
#    ---------------------------------------- 0.0/274.7 kB ? eta -:--:--
#    ------------------------------- ------- 225.3/274.7 kB 14.3 MB/s eta 0:00:01
#    -------------------------------------- - 266.2/274.7 kB 3.3 MB/s eta 0:00:01
#    -------------------------------------- - 266.2/274.7 kB 3.3 MB/s eta 0:00:01
#    -------------------------------------- - 266.2/274.7 kB 3.3 MB/s eta 0:00:01
#    -------------------------------------- - 266.2/274.7 kB 3.3 MB/s eta 0:00:01
#    -------------------------------------- - 266.2/274.7 kB 3.3 MB/s eta 0:00:01
#    -------------------------------------- - 266.2/274.7 kB 3.3 MB/s eta 0:00:01
#    -------------------------------------- 274.7/274.7 kB 847.8 kB/s eta 0:00:00
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading rapidfuzz-3.9.4-cp312-cp312-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---- ----------------------------------- 0.2/1.6 MB 5.0 MB/s eta 0:00:01
#    ------ --------------------------------- 0.3/1.6 MB 3.4 MB/s eta 0:00:01
#    --------- ------------------------------ 0.4/1.6 MB 2.7 MB/s eta 0:00:01
#    ------------- -------------------------- 0.5/1.6 MB 2.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.7/1.6 MB 2.8 MB/s eta 0:00:01
#    ------------------- -------------------- 0.8/1.6 MB 2.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.9/1.6 MB 2.8 MB/s eta 0:00:01
#    --------------------------- ------------ 1.1/1.6 MB 3.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.2/1.6 MB 2.9 MB/s eta 0:00:01
#    ------------------------------ --------- 1.2/1.6 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.4/1.6 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------- -- 1.5/1.6 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  1.6/1.6 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  1.6/1.6 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 2.3 MB/s eta 0:00:00
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# Downloading unstructured-0.15.0-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB 8.3 MB/s eta 0:00:01
#    ------ --------------------------------- 0.4/2.1 MB 4.5 MB/s eta 0:00:01
#    -------- ------------------------------- 0.5/2.1 MB 3.7 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.6/2.1 MB 3.3 MB/s eta 0:00:01
#    ------------ --------------------------- 0.6/2.1 MB 2.9 MB/s eta 0:00:01
#    ------------- -------------------------- 0.7/2.1 MB 2.6 MB/s eta 0:00:01
#    --------------- ------------------------ 0.8/2.1 MB 2.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.9/2.1 MB 2.5 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.1 MB 2.5 MB/s eta 0:00:01
#    --------------------- ------------------ 1.1/2.1 MB 2.5 MB/s eta 0:00:01
#    ------------------------- -------------- 1.3/2.1 MB 2.4 MB/s eta 0:00:01
#    --------------------------- ------------ 1.4/2.1 MB 2.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 2.5 MB/s eta 0:00:01
#    -------------------------------- ------- 1.7/2.1 MB 2.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.9/2.1 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------- -- 1.9/2.1 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 2.3 MB/s eta 0:00:00
# Downloading unstructured_client-0.24.1-py3-none-any.whl (41 kB)
#    ---------------------------------------- 0.0/41.9 kB ? eta -:--:--
#    ---------------------------------------- 41.9/41.9 kB 2.1 MB/s eta 0:00:00
# Using cached wrapt-1.16.0-cp312-cp312-win_amd64.whl (37 kB)
# Using cached certifi-2024.7.4-py3-none-any.whl (162 kB)
# Using cached charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl (100 kB)
# Downloading deepdiff-7.0.1-py3-none-any.whl (80 kB)
#    ---------------------------------------- 0.0/80.8 kB ? eta -:--:--
#    ----------------------------------- ---- 71.7/80.8 kB ? eta -:--:--
#    ---------------------------------------- 80.8/80.8 kB 1.5 MB/s eta 0:00:00
# Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Downloading jsonpath_python-1.0.6-py3-none-any.whl (7.6 kB)
# Using cached marshmallow-3.21.3-py3-none-any.whl (49 kB)
# Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading pypdf-4.3.0-py3-none-any.whl (295 kB)
#    ---------------------------------------- 0.0/295.7 kB ? eta -:--:--
#    ------------------------------------- - 286.7/295.7 kB 17.3 MB/s eta 0:00:01
#    ---------------------------------------- 295.7/295.7 kB 4.6 MB/s eta 0:00:00
# Using cached regex-2024.5.15-cp312-cp312-win_amd64.whl (268 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached soupsieve-2.5-py3-none-any.whl (36 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Using cached anyio-4.4.0-py3-none-any.whl (86 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (pyproject.toml): started
#   Building wheel for langdetect (pyproject.toml): finished with status 'done'
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993250 sha256=f334fe06747019bda328d6ba00aefd10254e0f24cbb0a86eae77f1d6e7119850
#   Stored in directory: c:\users\anoop maurya\appdata\local\pip\cache\wheels\c1\67\88\e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built langdetect
# Installing collected packages: filetype, wrapt, urllib3, typing-extensions, tqdm, tabulate, soupsieve, sniffio, regex, rapidfuzz, python-magic, python-iso639, pypdf, ordered-set, numpy, mypy-extensions, marshmallow, lxml, langdetect, jsonpath-python, joblib, idna, h11, click, charset-normalizer, chardet, certifi, backoff, typing-inspect, requests, nltk, httpcore, emoji, deepdiff, beautifulsoup4, anyio, requests-toolbelt, httpx, dataclasses-json, unstructured-client, unstructured
# Successfully installed anyio-4.4.0 backoff-2.2.1 beautifulsoup4-4.12.3 certifi-2024.7.4 chardet-5.2.0 charset-normalizer-3.3.2 click-8.1.7 dataclasses-json-0.6.7 deepdiff-7.0.1 emoji-2.12.1 filetype-1.2.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 idna-3.7 joblib-1.4.2 jsonpath-python-1.0.6 langdetect-1.0.9 lxml-5.2.2 marshmallow-3.21.3 mypy-extensions-1.0.0 nltk-3.8.1 numpy-1.26.4 ordered-set-4.1.0 pypdf-4.3.0 python-iso639-2024.4.27 python-magic-0.4.27 rapidfuzz-3.9.4 regex-2024.5.15 requests-2.32.3 requests-toolbelt-1.0.0 sniffio-1.3.1 soupsieve-2.5 tabulate-0.9.0 tqdm-4.66.4 typing-extensions-4.12.2 typing-inspect-0.9.0 unstructured-0.15.0 unstructured-client-0.24.1 urllib3-2.2.2 wrapt-1.16.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: unstructured 0.15.0 does not provide the extra 'all'

# %%
pip uninstall pdfminer[all]

# %%
from unstructured.partition.pdf import partition_pdf

chunks = partition_pdf(filename="oops.pdf",
                       chunking_strategy="basic",
                      extract_images_in_pdf=True,
                      infer_table_structure=True)

for index, chunk in enumerate(chunks):
  print(f"Chunk no {index+1} :", chunk)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from unstructured.partition.pdf import partition_pdf
#       3 chunks = partition_pdf(filename="oops.pdf",
#       4                        chunking_strategy="basic",
#       5                       extract_images_in_pdf=True,
#       6                       infer_table_structure=True)
#       8 for index, chunk in enumerate(chunks):
#
# File c:\Users\Anoop Maurya\Documents\GitHub\experiment-notebooks\.venv\Lib\site-packages\unstructured\partition\pdf.py:17
#      15 from pdfminer.layout import LTChar, LTContainer, LTImage, LTItem, LTTextBox
#      16 from pdfminer.pdftypes import PDFObjRef
# ---> 17 from pdfminer.utils import open_filename
#      18 from PIL import Image as PILImage
#      19 from pillow_heif import register_heif_opener
#
# ImportError: cannot import name 'open_filename' from 'pdfminer.utils' (c:\Users\Anoop Maurya\Documents\GitHub\experiment-notebooks\.venv\Lib\site-packages\pdfminer\utils.py)
